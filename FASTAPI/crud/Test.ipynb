# %%
print("Hello")

# %%
import json

userInfo= {
    "name":"satej",
    "Roll":55
}

def Demo(userInfo):
    with open("All_student.json","r") as f:
        alldata=json.load(f)

        print(alldata)

        alldata.append(userInfo)


    with open("All_student.json","w") as f2:
        json.dump(alldata,f2)


Demo(userInfo)
# Out:
# [{'name': 'user1', 'Roll': 1}, {'name': 'user2', 'Roll': 2}, {'name': 'user3', 'Roll': 3}]
