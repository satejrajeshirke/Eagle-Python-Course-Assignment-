# %%
"""
1. Create variables of all Python primitive data types.
 Print their: • Value  • Data Type  • Memory Address (id()) 
"""


Num=123
Percentage=73.60
Is_present=True
Com=1+2j
highest_num=None
str="satej"

print("Value:",Num,"  Datatype:",type(Num)," Memory Address(id):",id(Num))
print("Value:",Percentage,"  Datatype:",type(Percentage)," Memory Address(id):",id(Percentage))
print("Value:",Is_present,"  Datatype:",type(Is_present)," Memory Address(id):",id(Is_present))
print("Value:",Com,"  Datatype:",type(Com)," Memory Address(id):",id(Com))
print("Value:",highest_num,"  Datatype:",type(highest_num)," Memory Address(id):",id(highest_num))
print("Value:",str,"  Datatype:",type(str)," Memory Address(id):",id(str))
# Out:
# Value: 123   Datatype: <class 'int'>  Memory Address(id): 140710205154168
# Value: 73.6   Datatype: <class 'float'>  Memory Address(id): 3276103765776
# Value: True   Datatype: <class 'bool'>  Memory Address(id): 140710204252864
# Value: (1+2j)   Datatype: <class 'complex'>  Memory Address(id): 3276108211312
# Value: None   Datatype: <class 'NoneType'>  Memory Address(id): 140710204252928
# Value: satej   Datatype: <class 'str'>  Memory Address(id): 3276108718240

# %%
"""
Create three variables 
- a = 15 
- b = 4
 • Addition  • Subtraction  • Multiplication  • Division  • Floor Division  • Modulus  • Exponent 
"""

a=15
b=4
print("Addition OF two Numbers IS:",a+b)
print("Subtraction OF two Numbers is:",a-b)
print("Multiplication of Two Numbers is:",a*b)
print("Division OF Two NUmber is",a/b)
print("Floor Divison OF the Two NUmbers is:",a//b)
print("Modules of Two Numbers is:",a%b)
print("Explonet OF the Two NUmbers is :",a**b)
# Out:
# Addition OF two Numbers IS: 19
# Subtraction OF two Numbers is: 11
# Multiplication of Two Numbers is: 60
# Division OF Two NUmber is 3.75
# Floor Divison OF the Two NUmbers is: 3
# Modules of Two Numbers is: 3
# Explonet OF the Two NUmbers is : 50625

# %%
"""
3. Create two variables: - x = "100"
 - y = 50 • 
 Convert the variables so that you can perform arithmetic operations between them. 
"""

X="100"
y=50

z=int(X)

Add=z+y
print("addtion OF two Number is",Add)
# Out:
# addtion OF two Number is 150

# %%
#4. Predict the output before running the program, then verify.
a = 10 
b = 20 
print(a + b * 2)   #50
print((a + b) * 2) #60
print(a ** 2 + b) #120
print(a // 3) #9
print(a / 3)  # 3.33
# Out:
# 50
# 60
# 120
# 3
# 3.3333333333333335

# %%
"""
5. Write a program to calculate electricity bill. 
Use variables for: • Units Consumed  • Cost per Unit  • Calculate total bill and GST (18%). 

"""

Units_Consumed=112
cost_per_unit=12


Total=Units_Consumed*12
Gst=Total*18/100

total1=Total+Gst

print("total bill and GST:",total1)
# Out:
# total bill and GST: 1585.92

# %%
"""
Create a list of programming languages.
 - Check whether: 
 • "Python" exists.  • "Java" does not exist.  • "C++" exists.  • Use Membership Operators. 


"""

list=["python","C++"]

if "Java" not in list:
    print("Java not exits")

if "python" in list:
    print("python exits")

if "C++" in list:
    print("C++ exits")
# Out:
# Java not exits
# python exits
# C++ exits

# %%
"""
7. Write a program that converts:
 •  int → float  •  float → string  •  string → int  •  int → bool  •  bool → int 

"""
del str
num1=90
print(float(num1))

num2=78.90
print(str(num2))

num3="100"
print(int(num3))

num4=34
print(bool(num4))

num5= True
print(int(num5))
# Out:
# 90.0
# 78.9
# 100
# True
# 1

# %%
"""
8. Predict the output.
 a = 10 #10
 a += 5 #15
 a *= 2 #30
 a -= 8 #22
 a /= 4 # 5
 print(a) 
"""

a = 10 #10
a += 5 #15
a *= 2 #30
a -= 8 #22
a /= 4 # 5.5
print(a)
# Out:
# 5.5

# %%
"9. Predict the output. print(5 == 5.0) print(5 is 5.0) "
print(5 == 5.0) #True
print(5 is 5.0) #False
# Out:
# True
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\satej\AppData\Local\Temp\ipykernel_12512\3286776046.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 5.0) #True

# %%
"""
10. Create a program that stores product information.
 Store: • Product Name  • Price  • Quantity  Calculate: • Total Cost  • GST (18%)  • Final Amount
"""

product_name="Xyz"
price=50
Quantity=30
Gst=18

total = price*Quantity
gst1=total*18/100

print("final Amount is:",total+gst1)
# Out:
# final Amount is: 1770.0

# %%
"""
11. Write a program that checks whether a person can register for a driving license. 
Conditions: • Age ≥ 18  • Indian Citizen 

"""

age=19
Indian=True

if age >= 18 and Indian:
    print("Eligible for driving Licence")

else:
    print("Not Eligible for Driving Licence")
# Out:
# Eligible for driving Licence

# %%
"""
12. Predict the output.
 a = [10,20]
 b = a #b=[10,20]
 c = [10,20] 
 print(a == b) #true
 print(a is b) #true
 print(a == c) True
 print(a is c) False
 print(id(a)) #1234
 print(id(b)) #1234
 print(id(c)) #12345

"""

a = [10,20]
b = a #b=[10,20]
c = [10,20] 
print(a == b) #true
print(a is b) #true
print(a == c) #True
print(a is c) #False
print(id(a)) #1234
print(id(b)) #1234
print(id(c)) #12345
# Out:
# True
# True
# True
# False
# 3276109502656
# 3276109502656
# 3276109428032
