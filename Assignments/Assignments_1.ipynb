# %%
"""
Q1. Personal Profile Program Write a
 Python program to store the following information using variables and display
   it in a well-formatted way.
 • Name 
 • Age 
 • College Name 
 • City  
 • Course Name
"""

name="Satej Mahendra Rajeshirke"
age=22
Collage_name="Jaihind Collge Of Engineeing kuran,Pune "
city="pune"
course="Computer Engineering"
print("Name:",name)
print("Age:",age)
print("Collage Name:",Collage_name)
print("Course Name:",course)
# Out:
# Name: Satej Mahendra Rajeshirke
# Age: 22
# Collage Name: Jaihind Collge Of Engineeing kuran,Pune
# Course Name: Computer Engineering

# %%
"""
Q2. Student Report Create variables for the following student details and print
 them:
   • Student Name 
   • Roll Number  
   • Branch  
   • Percentage  
   • Passed (True/False) 
"""

Student_Name="Satej Mahendra Rajeshirke"
Roll_Number=50
Branch="Computer Engineering"
Percentage=93.4
Passed=True

print("Student Name:",Student_Name)
print("Roll Number:",Roll_Number)
print("Branch:",Branch)
print("Percentage:",Percentage)
print("Passed:",Passed)
# Out:
# Student Name: Satej Mahendra Rajeshirke
# Roll Number: 50
# Branch: Computer Engineering
# Percentage: 93.4
# Passed: True

# %%
Student_Name="Satej Mahendra Rajeshirke"
Roll_Number=50
Branch="computer Engineering"
Student_ID=1267
Mobile_No=6767676767
Blood_grp="AB+"
Year="4th"
Passing_year=2026
admisssion_year=2022
institute_code=84
University="Sppu"

print("Student Name:",Student_Name)
print("Roll_Number:",Roll_Number)
print("Branch:",Branch)
print("Stundent ID:",Student_ID)
print("Mobile NUmber:",Mobile_No)
print("Year Of Studying:",Year)
print("Passing Year:",Passing_year)
print("Admission Year:",admisssion_year)
print("Institute Code:",institute_code)
print("University Name:",University)
# Out:
# Student Name: Satej Mahendra Rajeshirke
# Roll_Number: 50
# Branch: computer Engineering
# Stundent ID: 1267
# Mobile NUmber: 6767676767
# Year Of Studying: 4th
# Passing Year: 2026
# Admission Year: 2022
# Institute Code: 84
# University Name: Sppu

# %%
"""
Q4. Comments Practice Write a Python program that contains:
 • At least 3 single-line comments 
• 1 multi-line comment  
• A program that prints a short introduction about yourself

"""

# this is single Line Comment 1
# this is Single Line Commnet 2
# this is Single Line Commnet 3 

"""
THis is Multin multi line 
This is MUlti Line Commnet
"""

print("My Name is Satej Mahendra Rajeshirke. I am from Satara. I am Currently Complted The Degree In Computer Engineering in 2026.")
# Out:
# My Name is Satej Mahendra Rajeshirke. I am from Satara. I am Currently Complted The Degree In Computer Engineering in 2026.

# %%
"""
Q5. Correct the Errors Rewrite the following invalid variable names into valid Python identifiers and assign appropriate values to them.
 • 2student 
 • student-name 
 • student name 
 • class 
 • for 
 • employee@id 

"""

Student = "Final Year Student"
Student_Name="Satej Mahendra Rajeshirke"
Class_Name ="Computer"
For_loop ="Done"
employee_id = 105


print("Student:",Student)
print("Student Name",Student_Name)
print("Class Name:",Class_Name)
print("For Loop:",For_loop)
print("Employee Id:",employee_id)
# Out:
# Student: Final Year Student
# Student Name Satej Mahendra Rajeshirke
# Class Name: Computer
# For Loop: Done
# Employee Id: 105
