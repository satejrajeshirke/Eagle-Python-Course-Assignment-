# %%
try:
    num1=int(input("Enter num1"))
     num1=int(input("Enter num1"))
# Out:
#   Cell In[1], line 3
#     num1=int(input("Enter num1"))
#     ^
# IndentationError: unexpected indent

# %%
# Out:
# [1, 2, 3, 4, 5, 6]
# length of list 6
# [3, 4]
# 6

# %%
list=[1,2,3]
listone=[4,5,6]

listtwo=list + listone
print(listtwo)

length=len(listtwo)
print("length of list",length)

center = length//2

if length  % 2 == 1:
    print(listtwo[center])
else:
    print(listtwo[center-1:center+1])
    print(listtwo[center-1]+listtwo[center])

# %%
list = [1, 2, 3]
listone = [4, 5, 6]

listtwo = list + listone
print(listtwo)

length = len(listtwo)
print("length of list", length)

center = length // 2

if length % 2 == 1:
    print(listtwo[center])
else:
    print(listtwo[center-1:center+1])
    print(listtwo[center-1] + listtwo[center])
# Out:
# [1, 2, 3, 4, 5, 6]
# length of list 6
# [3, 4]
# 7

# %%
for i in range(9):
    print("*",end="")
print()

space=" "
spacecount=1
star="*"
for j in range(9):
    print(star,space*2,star,space,)
# Out:
# *********
# *********
